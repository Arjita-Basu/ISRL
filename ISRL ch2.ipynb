# %% [markdown]
# **QUESTIONS ON THE DATA 'COLLEGE'**

# %%
df1=read.csv("../input/College.csv")
df1
# Out:
#     X                                       Private Apps  Accept Enroll
# 1   Abilene Christian University            Yes      1660  1232   721
# 2   Adelphi University                      Yes      2186  1924   512
# 3   Adrian College                          Yes      1428  1097   336
# 4   Agnes Scott College                     Yes       417   349   137
# 5   Alaska Pacific University               Yes       193   146    55
# 6   Albertson College                       Yes       587   479   158
# 7   Albertus Magnus College                 Yes       353   340   103
# 8   Albion College                          Yes      1899  1720   489
# 9   Albright College                        Yes      1038   839   227
# 10  Alderson-Broaddus College               Yes       582   498   172
# 11  Alfred University                       Yes      1732  1425   472
# 12  Allegheny College                       Yes      2652  1900   484
# ...

# %%
rownames(df1)=df1[,1]
df1=df1[,-1]
df1
# Out:
#                                         Private Apps  Accept Enroll Top10perc
# Abilene Christian University            Yes      1660  1232   721   23
# Adelphi University                      Yes      2186  1924   512   16
# Adrian College                          Yes      1428  1097   336   22
# Agnes Scott College                     Yes       417   349   137   60
# Alaska Pacific University               Yes       193   146    55   16
# Albertson College                       Yes       587   479   158   38
# Albertus Magnus College                 Yes       353   340   103   17
# Albion College                          Yes      1899  1720   489   37
# Albright College                        Yes      1038   839   227   30
# Alderson-Broaddus College               Yes       582   498   172   21
# Alfred University                       Yes      1732  1425   472   37
# Allegheny College                       Yes      2652  1900   484   44
# ...

# %%
summary(df1)
# Out:
#  Private        Apps           Accept          Enroll       Top10perc
#  No :212   Min.   :   81   Min.   :   72   Min.   :  35   Min.   : 1.00
#  Yes:565   1st Qu.:  776   1st Qu.:  604   1st Qu.: 242   1st Qu.:15.00
#            Median : 1558   Median : 1110   Median : 434   Median :23.00
#            Mean   : 3002   Mean   : 2019   Mean   : 780   Mean   :27.56
#            3rd Qu.: 3624   3rd Qu.: 2424   3rd Qu.: 902   3rd Qu.:35.00
#            Max.   :48094   Max.   :26330   Max.   :6392   Max.   :96.00
#    Top25perc      F.Undergrad     P.Undergrad         Outstate
#  Min.   :  9.0   Min.   :  139   Min.   :    1.0   Min.   : 2340
#  1st Qu.: 41.0   1st Qu.:  992   1st Qu.:   95.0   1st Qu.: 7320
#  Median : 54.0   Median : 1707   Median :  353.0   Median : 9990
#  Mean   : 55.8   Mean   : 3700   Mean   :  855.3   Mean   :10441
#  3rd Qu.: 69.0   3rd Qu.: 4005   3rd Qu.:  967.0   3rd Qu.:12925
#  Max.   :100.0   Max.   :31643   Max.   :21836.0   Max.   :21700
# ...

# %%
pairs(df1[,1:10])

# %%
attach(df1)
# Out:
# The following objects are masked from df1 (pos = 5):
#
#     Accept, Apps, Books, Enroll, Expend, F.Undergrad, Grad.Rate,
#     Outstate, P.Undergrad, perc.alumni, Personal, PhD, Private,
#     Room.Board, S.F.Ratio, Terminal, Top10perc, Top25perc

# %%
plot(Private,Outstate,horizontal=T,col=20,col.main=10,xlab='Private',ylab='Outstate',main='Outstate vs Private')

# %%
Elite=rep("No",nrow(df1))
Elite[df1$Top10perc>50]="Yes"
Elite=as.factor(Elite)
df1=data.frame(df1,Elite)

# %%
summary(Elite)
# Out:
#  No Yes
# 699  78

# %%
plot(Elite,Outstate,horizontal=T,col=20,col.main=10,xlab='Elite',ylab='Outstate',main='Outstate vs Elite')

# %%
par(mfrow=c(3,3))
hist(Apps,col=2)
hist(Accept,col=3)
hist(Enroll,col=4)
hist(Top10perc,col=5)
hist(Top25perc,col=6)
hist(F.Undergrad,col=7)
hist(P.Undergrad,col=8)
hist(Outstate,col=9)
hist(Books,col=10)

# %% [markdown]
# **QUESTIONS ON THE DATA 'AUTO'**

# %%
df2=read.csv("../input/Auto.csv",header=T,na.string='?')
df2
# Out:
#     mpg cylinders displacement horsepower weight acceleration year origin
# 1   18  8         307          130        3504   12.0         70   1
# 2   15  8         350          165        3693   11.5         70   1
# 3   18  8         318          150        3436   11.0         70   1
# 4   16  8         304          150        3433   12.0         70   1
# 5   17  8         302          140        3449   10.5         70   1
# 6   15  8         429          198        4341   10.0         70   1
# 7   14  8         454          220        4354    9.0         70   1
# 8   14  8         440          215        4312    8.5         70   1
# 9   14  8         455          225        4425   10.0         70   1
# 10  15  8         390          190        3850    8.5         70   1
# 11  15  8         383          170        3563   10.0         70   1
# 12  14  8         340          160        3609    8.0         70   1
# 13  15  8         400          150        3761    9.5         70   1
# ...

# %%
attach(df2)
# Out:
# The following objects are masked from df2 (pos = 5):
#
#     acceleration, cylinders, displacement, horsepower, mpg, name,
#     origin, weight, year

# %%
df2=na.omit(df2)

# %%
range(cylinders)
# Out:
# [1] 3 8

# %%
range(displacement)
# Out:
# [1]  68 455

# %%
range(horsepower)
# Out:
# [1] NA NA

# %%
range(weight)
# Out:
# [1] 1613 5140

# %%
range(acceleration)
# Out:
# [1]  8.0 24.8

# %%
x=df2[,1:6]
summary(x)
# Out:
#       mpg          cylinders      displacement     horsepower        weight
#  Min.   : 9.00   Min.   :3.000   Min.   : 68.0   Min.   : 46.0   Min.   :1613
#  1st Qu.:17.00   1st Qu.:4.000   1st Qu.:105.0   1st Qu.: 75.0   1st Qu.:2225
#  Median :22.75   Median :4.000   Median :151.0   Median : 93.5   Median :2804
#  Mean   :23.45   Mean   :5.472   Mean   :194.4   Mean   :104.5   Mean   :2978
#  3rd Qu.:29.00   3rd Qu.:8.000   3rd Qu.:275.8   3rd Qu.:126.0   3rd Qu.:3615
#  Max.   :46.60   Max.   :8.000   Max.   :455.0   Max.   :230.0   Max.   :5140
#   acceleration
#  Min.   : 8.00
#  1st Qu.:13.78
#  Median :15.50
#  Mean   :15.54
#  3rd Qu.:17.02
#  Max.   :24.80

# %%
y=df2[10:85,]
x=y[,1:6]
summary(x)
# Out:
#       mpg          cylinders      displacement     horsepower
#  Min.   : 9.00   Min.   :3.000   Min.   : 70.0   Min.   : 46.00
#  1st Qu.:14.00   1st Qu.:4.000   1st Qu.:112.2   1st Qu.: 87.75
#  Median :19.00   Median :6.000   Median :212.5   Median : 98.50
#  Mean   :19.46   Mean   :5.882   Mean   :224.2   Mean   :120.05
#  3rd Qu.:25.00   3rd Qu.:8.000   3rd Qu.:342.5   3rd Qu.:156.25
#  Max.   :35.00   Max.   :8.000   Max.   :455.0   Max.   :225.00
#      weight      acceleration
#  Min.   :1613   Min.   : 8.00
#  1st Qu.:2262   1st Qu.:13.00
#  Median :2948   Median :14.50
#  Mean   :3151   Mean   :14.77
#  3rd Qu.:4107   3rd Qu.:16.12
#  Max.   :5140   Max.   :23.50

# %%
pairs(df2,col=8, main ="A PAIR PLOT OF ALL THE VARIABLES")

# %% [markdown]
# ****QUESTIONS ON THE DATA 'BOSTON'****

# %%
library(MASS)
Boston
# Out:
#     crim     zn   indus chas nox   rm    age   dis    rad tax ptratio black
# 1   0.00632  18.0 2.31  0    0.538 6.575  65.2 4.0900 1   296 15.3    396.90
# 2   0.02731   0.0 7.07  0    0.469 6.421  78.9 4.9671 2   242 17.8    396.90
# 3   0.02729   0.0 7.07  0    0.469 7.185  61.1 4.9671 2   242 17.8    392.83
# 4   0.03237   0.0 2.18  0    0.458 6.998  45.8 6.0622 3   222 18.7    394.63
# 5   0.06905   0.0 2.18  0    0.458 7.147  54.2 6.0622 3   222 18.7    396.90
# 6   0.02985   0.0 2.18  0    0.458 6.430  58.7 6.0622 3   222 18.7    394.12
# 7   0.08829  12.5 7.87  0    0.524 6.012  66.6 5.5605 5   311 15.2    395.60
# 8   0.14455  12.5 7.87  0    0.524 6.172  96.1 5.9505 5   311 15.2    396.90
# 9   0.21124  12.5 7.87  0    0.524 5.631 100.0 6.0821 5   311 15.2    386.63
# 10  0.17004  12.5 7.87  0    0.524 6.004  85.9 6.5921 5   311 15.2    386.71
# 11  0.22489  12.5 7.87  0    0.524 6.377  94.3 6.3467 5   311 15.2    392.52
# ...

# %%
dim(Boston)
# Out:
# [1] 506  14

# %% [markdown]
# The table has 506 rows and 14 columns.Here rows represent the dependent variables and columns represent the independent variables.

# %%
attach(Boston)

# %% [markdown]
# DEPENDENCY OF TAX ON OTHER VARIABLES

# %%
par(mfrow=c(2,2))
plot(tax,crim)
plot(tax,zn)
plot(tax,indus)
plot(tax,chas)

# %%
par(mfrow=c(2,2))
plot(tax,nox)
plot(tax,rm)
plot(tax,age)
plot(tax,dis)

# %%
par(mfrow=c(3,2))
plot(tax,rad)
plot(tax,ptratio)
plot(tax,black)
plot(tax,lstat)
plot(tax,medv)

# %% [markdown]
# **This data frame contains the following columns:
# crim
# per capita crime rate by town.
# zn
# proportion of residential land zoned for lots over 25,000 sq.ft.
# indus
# proportion of non-retail business acres per town.
# chas
# Charles River dummy variable (= 1 if tract bounds river; 0 otherwise).
# nox
# nitrogen oxides concentration (parts per 10 million).
# rm
# average number of rooms per dwelling.
# age
# proportion of owner-occupied units built prior to 1940.
# dis
# weighted mean of distances to five Boston employment centres.
# rad
# index of accessibility to radial highways.
# tax
# full-value property-tax rate per 10,000 dollars.
# ptratio
# pupil-teacher ratio by town.
# black
# 1000(Bk−0.63)21000(Bk−0.63)2 where BkBk is the proportion of blacks by town.
# lstat
# lower status of the population (percent).
# medv
# median value of owner-occupied homes in 1000dollars.**

# %% [markdown]
# we cannot relate crime to the other variables.

# %%
range(crim)
# Out:
# [1]  0.00632 88.97620

# %%
range(tax)
# Out:
# [1] 187 711

# %%
range(ptratio)
# Out:
# [1] 12.6 22.0

# %%
summary(ptratio)
# Out:
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#   12.60   17.40   19.05   18.46   20.20   22.00
